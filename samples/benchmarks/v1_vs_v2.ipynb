# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pickle 

with open('data.pickle') as f:
    data = pickle.load(f)
    
packets = data['packet']

# %%
to_plot = (('dell', '2.7.8'),
           ('dell', 'pypy-2.3.1'),

           ('v2', '2.7.8'),
           ('v2', 'pypy-2.3.1'))

# %%
indices = array([0.5, 1.0, 
                 2.0, 2.5])

color = {'serial': 'b',
         'forged': 'r',
         'pypot': 'g'}

width = 0.4

with xkcd():
    fig = plt.figure()
    ax = fig.add_axes((0.1, 0.2, 0.8, 0.7))
    
    for s in ['pypot', 'forged', 'serial']:
        x = [mean(packets[s][b][p]) * 1000 for b, p in to_plot]
        ax.bar(indices, x, width, color=color[s])
    
    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')

    ax.set_xticks(indices + width/2)
    
    ax.set_xticklabels(['2.7.8\n                      V1',
                        'PyPy',
                        '2.7.8\n                      V2',
                        'PyPy'])

    plt.ylabel('time (ms)')
    plt.title("BOARDS COMPARISON")

# %%
v1 = packets['pypot']['dell']['pypy-2.3.1']
v2 = packets['pypot']['v2']['pypy-2.3.1']

print 'Improvment {}%'.format(100 * (1 - mean(v2) / mean(v1)))
# Out:
# Improvment 0.827812307767%
